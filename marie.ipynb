# %% [markdown]
# <a href="https://colab.research.google.com/github/espanolamarie/ESPA-OLA_BSIS3_PROFELECTIVE1/blob/main/marie.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df= pd.read_csv('https://raw.githubusercontent.com/espanolamarie/ESPA-OLA_BSIS3_PROFELECTIVE1/refs/heads/main/dataset.csv')

# %%
print("Orignal row count" ,len(df))
# Out:
# Orignal row count 52

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                52 non-null     object
#  1   Symbol              52 non-null     object
#  2   Series              52 non-null     object
#  3   Prev Close          52 non-null     float64
#  4   Open                52 non-null     float64
#  5   High                52 non-null     float64
#  6   Low                 52 non-null     float64
#  7   Last                52 non-null     float64
#  8   Close               52 non-null     float64
#  9   VWAP                52 non-null     float64
#  10  Volume              52 non-null     int64
#  11  Turnover            52 non-null     float64
#  12  Trades              0 non-null      float64
#  13  Deliverable Volume  52 non-null     int64
#  14  %Deliverble         52 non-null     float64
# ...

# %%
print(df)
# Out:
#           Date Symbol Series  Prev Close     Open     High     Low     Last  \
# 0   28/08/2006  TECHM     EQ      365.00   521.00   569.00  502.00   553.00
# 1   29/08/2006  TECHM     EQ      554.25   555.00   563.90  535.55   536.10
# 2   30/08/2006  TECHM     EQ      539.30   537.00   542.90  521.50   529.00
# 3   31/08/2006  TECHM     EQ      528.10   525.00   544.00  515.00   539.35
# 4   01/09/2006  TECHM     EQ      538.45   539.00   549.00  535.10   541.35
# 5   04/09/2006  TECHM     EQ      541.85   542.00   549.00  452.80   542.00
# 6   05/09/2006  TECHM     EQ      543.95   544.00   556.00  538.50   551.50
# 7   06/09/2006  TECHM     EQ      552.70   554.70   562.50  538.00   540.00
# 8   07/09/2006  TECHM     EQ      541.25   545.00   545.00  530.00   536.25
# 9   08/09/2006  TECHM     EQ      537.30   538.80   544.90  531.55   531.60
# 10  11/09/2006  TECHM     EQ      534.80   539.95   545.00  532.25   533.10
# ...

# %%
print(df[df.isnull().any(axis=1)])
# Out:
#           Date Symbol Series  Prev Close     Open     High     Low     Last  \
# 0   28/08/2006  TECHM     EQ      365.00   521.00   569.00  502.00   553.00
# 1   29/08/2006  TECHM     EQ      554.25   555.00   563.90  535.55   536.10
# 2   30/08/2006  TECHM     EQ      539.30   537.00   542.90  521.50   529.00
# 3   31/08/2006  TECHM     EQ      528.10   525.00   544.00  515.00   539.35
# 4   01/09/2006  TECHM     EQ      538.45   539.00   549.00  535.10   541.35
# 5   04/09/2006  TECHM     EQ      541.85   542.00   549.00  452.80   542.00
# 6   05/09/2006  TECHM     EQ      543.95   544.00   556.00  538.50   551.50
# 7   06/09/2006  TECHM     EQ      552.70   554.70   562.50  538.00   540.00
# 8   07/09/2006  TECHM     EQ      541.25   545.00   545.00  530.00   536.25
# 9   08/09/2006  TECHM     EQ      537.30   538.80   544.90  531.55   531.60
# 10  11/09/2006  TECHM     EQ      534.80   539.95   545.00  532.25   533.10
# ...

# %%
print(df.isnull().sum())
# Out:
# Date                   0
# Symbol                 0
# Series                 0
# Prev Close             0
# Open                   0
# High                   0
# Low                    0
# Last                   0
# Close                  0
# VWAP                   0
# Volume                 0
# Turnover               0
# Trades                52
# Deliverable Volume     0
# %Deliverble            0
# dtype: int64

# %%
df.fillna(0, inplace= True)

# %%
df["Trades"] =df["Trades"].fillna(df["Trades"].mode()[0])

# %%
print(df)
# Out:
#           Date Symbol Series  Prev Close     Open     High     Low     Last  \
# 0   28/08/2006  TECHM     EQ      365.00   521.00   569.00  502.00   553.00
# 1   29/08/2006  TECHM     EQ      554.25   555.00   563.90  535.55   536.10
# 2   30/08/2006  TECHM     EQ      539.30   537.00   542.90  521.50   529.00
# 3   31/08/2006  TECHM     EQ      528.10   525.00   544.00  515.00   539.35
# 4   01/09/2006  TECHM     EQ      538.45   539.00   549.00  535.10   541.35
# 5   04/09/2006  TECHM     EQ      541.85   542.00   549.00  452.80   542.00
# 6   05/09/2006  TECHM     EQ      543.95   544.00   556.00  538.50   551.50
# 7   06/09/2006  TECHM     EQ      552.70   554.70   562.50  538.00   540.00
# 8   07/09/2006  TECHM     EQ      541.25   545.00   545.00  530.00   536.25
# 9   08/09/2006  TECHM     EQ      537.30   538.80   544.90  531.55   531.60
# 10  11/09/2006  TECHM     EQ      534.80   539.95   545.00  532.25   533.10
# ...

# %%
df_drop_rows = df. dropna()

# %%
print(df[df.isnull().any(axis=1)])
# Out:
# Empty DataFrame
# Columns: [Date, Symbol, Series, Prev Close, Open, High, Low, Last, Close, VWAP, Volume, Turnover, Trades, Deliverable Volume, %Deliverble]
# Index: []

# %%
print(df)
# Out:
#           Date Symbol Series  Prev Close     Open     High     Low     Last  \
# 0   28/08/2006  TECHM     EQ      365.00   521.00   569.00  502.00   553.00
# 1   29/08/2006  TECHM     EQ      554.25   555.00   563.90  535.55   536.10
# 2   30/08/2006  TECHM     EQ      539.30   537.00   542.90  521.50   529.00
# 3   31/08/2006  TECHM     EQ      528.10   525.00   544.00  515.00   539.35
# 4   01/09/2006  TECHM     EQ      538.45   539.00   549.00  535.10   541.35
# 5   04/09/2006  TECHM     EQ      541.85   542.00   549.00  452.80   542.00
# 6   05/09/2006  TECHM     EQ      543.95   544.00   556.00  538.50   551.50
# 7   06/09/2006  TECHM     EQ      552.70   554.70   562.50  538.00   540.00
# 8   07/09/2006  TECHM     EQ      541.25   545.00   545.00  530.00   536.25
# 9   08/09/2006  TECHM     EQ      537.30   538.80   544.90  531.55   531.60
# 10  11/09/2006  TECHM     EQ      534.80   539.95   545.00  532.25   533.10
# ...

# %%
print(df.isnull().sum())
# Out:
# Date                  0
# Symbol                0
# Series                0
# Prev Close            0
# Open                  0
# High                  0
# Low                   0
# Last                  0
# Close                 0
# VWAP                  0
# Volume                0
# Turnover              0
# Trades                0
# Deliverable Volume    0
# %Deliverble           0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                52 non-null     object
#  1   Symbol              52 non-null     object
#  2   Series              52 non-null     object
#  3   Prev Close          52 non-null     float64
#  4   Open                52 non-null     float64
#  5   High                52 non-null     float64
#  6   Low                 52 non-null     float64
#  7   Last                52 non-null     float64
#  8   Close               52 non-null     float64
#  9   VWAP                52 non-null     float64
#  10  Volume              52 non-null     int64
#  11  Turnover            52 non-null     float64
#  12  Trades              52 non-null     float64
#  13  Deliverable Volume  52 non-null     int64
#  14  %Deliverble         52 non-null     float64
# ...
